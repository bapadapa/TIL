# %%
import matplotlib.pyplot as plt
import numpy as np

from sklearn import datasets
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

iris = datasets.load_iris()

X = iris.data
y = iris.target
target_names = iris.target_names

lda = LinearDiscriminantAnalysis()
X_r2 = lda.fit(X, y).transform(X)

colors = ['navy', 'turquoise', 'darkorange']
lw = 2

for color, i, target_name in zip(colors, [0, 1, 2], target_names):
    plt.scatter(X_r2[y == i, 0], X_r2[y == i, 1], alpha=.8, color=color,
                label=target_name)
plt.legend(loc='best', shadow=False, scatterpoints=1)
plt.title('LDA of IRIS dataset')

plt.show()

# %%
lda = LinearDiscriminantAnalysis(n_components=1)
X_r1 = lda.fit(X, y).transform(X)
setosa = X_r2[y == 0]
versicolor = X_r2[y == 1]
virginica = X_r2[y == 2]

print("setosa range is %f ~ %f" % (np.min(setosa), np.max(setosa)))
print("versicolor range is %f ~ %f" % (np.min(versicolor), np.max(versicolor)))
print("virginica range is %f ~ %f" % (np.min(virginica), np.max(virginica)))
# Out:
# setosa range is -9.869366 ~ 2.755586
# versicolor range is -2.616934 ~ 4.495674
# virginica range is -2.144179 ~ 9.188293

# %%
import numpy as np
import pandas as pd

#웹 / 랜더링
import dash 
import dash_html_components as html
from dash.dependencies import Input, Output
import dash_core_components as dcc

# 데이터
import plotly.express as px

# %%
title = html.H1('제목 💋')
subTitle = html.H6('My First Dash App 😎')
radio1 = dcc.RadioItems(
            id = 'radio-team',
            options =[
                {'label':str(i)+'조','value': str(i)} for i in range(1,7)
            ]
        )

# Dash instance
app = dash.Dash(__name__)
# front-end 화면구성
app.layout = html.Div(
    [ 
        title,
        subTitle,
        html.Hr(),
        radio1,
        html.Div(id = 'selected-team'),
        html.Div(id = 'selected-name')

    ]

)



@app.callback(
    Output('selected-team','children'),
    Input('radio-team','value')
)
def update_team(team):
    menu = ['라면','피자','짜장면','떡볶이']
    person = ['내','너']
    names = [ {'label':i,'value':i} for i in person]
    x = np.random.choice(menu)
    y = np.random.choice(person)
    # return html.H3("{}조를. 선택하였습니다.".format(team)) 
    return html.Div(
                [
                    html.H3("{}조를. 선택하였습니다.".format(team)),
                    html.Hr(),
                    html.H3("선택한 메뉴는  {} 입니다.".format(x)),
                    # html.H3("{}가 쏜다~".format(y))]
                    dcc.Dropdown(
                    id = 'drop-down-name',
                    options = names
                    )
                ]
    )
@app.callback(
    Output('selected-name','children'),
    Input('drop-down-name','value')
)
def update_name(name):
    score = np.random.choice(['A','B','C','D','F'])
    out =  html.H3('{}의 학점은 {}입니다.'.format(name,score))
    recom = np.where( score == 'A' or score == 'B','잘하셨습니다.',
                np.where(score == 'C' or socre =='D',"노력하세요",'낙제점입니다.' ))
    return html.Div(
        out,
        html.H3(recom)
    )

# %%
app.run_server()
# Out:
# :\Users\painc\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\painc\Anaconda3\lib\site-packages\dash\dash.py", line 1079, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\painc\Anaconda3\lib\site-packages\dash\dash.py", line 1010, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-78-6355919e6798>", line 59, in update_name
#     np.where(score == 'C' or socre =='D',"노력하세요",'낙제점입니다.' ))
# NameError: name 'socre' is not defined
# 127.0.0.1 - - [15/Jun/2021 13:14:14] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\painc\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
# ...
